# %%
# %python
dbutils.widgets.removeAll()

# %%
# %sql
CREATE WIDGET TEXT catalogo DEFAULT "etl_supermercado";
CREATE WIDGET TEXT usuario  DEFAULT "";

# %%
# %sql
USE CATALOG ${catalogo};

GRANT USE CATALOG ON CATALOG ${catalogo} TO `fyamile.0428@gmail.com`;
GRANT USE SCHEMA ON SCHEMA ${catalogo}.golden TO `fyamile.0428@gmail.com`;

GRANT SELECT ON TABLE ${catalogo}.golden.ventas_por_departamento TO `fyamile.0428@gmail.com`;
GRANT SELECT ON TABLE ${catalogo}.golden.top_productos TO `fyamile.0428@gmail.com`;
GRANT SELECT ON TABLE ${catalogo}.golden.frecuencia_usuarios TO `fyamile.0428@gmail.com`;

# %%
# %sql
SHOW GRANTS ON SCHEMA ${catalogo}.golden;
