-- %%
CREATE WIDGET TEXT catalogo DEFAULT "etl_supermercado";

-- %%
REVOKE SELECT ON TABLE ${catalogo}.golden.ventas_por_departamento FROM `fyamile.0428@gmail.com`;
REVOKE SELECT ON TABLE ${catalogo}.golden.top_productos FROM `fyamile.0428@gmail.com`;
REVOKE SELECT ON TABLE ${catalogo}.golden.frecuencia_usuarios FROM `fyamile.0428@gmail.com`;

-- %%
REVOKE SELECT ON TABLE ${catalogo}.silver.ventas_detalle FROM `fyamile.0428@gmail.com`;

-- %%
REVOKE USE SCHEMA ON SCHEMA ${catalogo}.golden FROM `fyamile.0428@gmail.com`;
REVOKE USE SCHEMA ON SCHEMA ${catalogo}.silver FROM `fyamile.0428@gmail.com`;

REVOKE USE SCHEMA ON SCHEMA ${catalogo}.bronze FROM `fyamile.0428@gmail.com`;

-- %%
REVOKE USE CATALOG ON CATALOG ${catalogo} FROM `fyamile.0428@gmail.com`;
